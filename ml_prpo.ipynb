# %%
import pandas as pd
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
from sklearn import metrics
import numpy as np
from sklearn.model_selection import GridSearchCV
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 from sklearn.naive_bayes import BernoulliNB
#       3 from sklearn.naive_bayes import GaussianNB
#       4 from sklearn.naive_bayes import MultinomialNB
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
df = pd.read_csv('/content/tested.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df = df.dropna(how = 'all')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df['Pclass'].unique()
# Out:
# array([3, 2, 1])

# %%
df['Survived'].isna().sum()
# Out:
# 0

# %%
df['Survived'] = df['Survived'].astype('int8')
df['Survived'].unique()
# Out:
# array([0, 1], dtype=int8)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Name'].tolist()
# Out:
# ['Kelly, Mr. James',
#  'Wilkes, Mrs. James (Ellen Needs)',
#  'Myles, Mr. Thomas Francis',
#  'Wirz, Mr. Albert',
#  'Hirvonen, Mrs. Alexander (Helga E Lindqvist)',
#  'Svensson, Mr. Johan Cervin',
#  'Connolly, Miss. Kate',
#  'Caldwell, Mr. Albert Francis',
#  'Abrahim, Mrs. Joseph (Sophie Halaut Easu)',
#  'Davies, Mr. John Samuel',
#  'Ilieff, Mr. Ylio',
#  'Jones, Mr. Charles Cresson',
#  'Snyder, Mrs. John Pillsbury (Nelle Stevenson)',
#  'Howard, Mr. Benjamin',
#  'Chaffee, Mrs. Herbert Fuller (Carrie Constance Toogood)',
#  'del Carlo, Mrs. Sebastiano (Argenia Genovesi)',
#  'Keane, Mr. Daniel',
#  'Assaf, Mr. Gerios',
#  'Ilmakangas, Miss. Ida Livija',
#  'Assaf Khalil, Mrs. Mariana (Miriam")"',
#  'Rothschild, Mr. Martin',
#  'Olsen, Master. Artur Karl',
#  'Flegenheim, Mrs. Alfred (Antoinette)',
#  'Williams, Mr. Richard Norris II',
#  'Ryerson, Mrs. Arthur Larned (Emily Maria Borie)',
#  'Robins, Mr. Alexander A',
#  'Ostby, Miss. Helene Ragnhild',
# ...

# %%
def func(x):
    items = x.split(', ')
    items = items[1].split('. ')
    title = items[0]
    return title

series = df['Name'].apply(func)
series
# Out:
# 0          Mr
# 1         Mrs
# 2          Mr
# 3          Mr
# 4         Mrs
#         ...
# 413        Mr
# 414      Dona
# 415        Mr
# 416        Mr
# 417    Master
# Name: Name, Length: 418, dtype: object

# %%
series.unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Ms', 'Col', 'Rev', 'Dr', 'Dona'],
#       dtype=object)

# %%
series = series.replace({'Col': 'Colonel',
                         'Dona': 'Mrs',
                         'Rev': 'Reverend'})
series.unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Ms', 'Colonel', 'Reverend', 'Dr'],
#       dtype=object)

# %%
i = df.columns.tolist().index('Name')
df.insert(i, 'title', series)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-7831bb5c5f0b> in <cell line: 2>()
#       1 i = df.columns.tolist().index('Name')
# ----> 2 df.insert(i, 'title', series)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    4815         if not allow_duplicates and column in self.columns:
#    4816             # Should this be a different kind of error??
# -> 4817             raise ValueError(f"cannot insert {column}, already exists")
#    4818         if not isinstance(loc, int):
#    4819             raise TypeError("loc must be int")
#
# ValueError: cannot insert title, already exists

# %%
df
# Out:
#      PassengerId  Survived  Pclass   title  \
# 0            892         0       3      Mr
# 1            893         1       3     Mrs
# 2            894         0       2      Mr
# 3            895         0       3      Mr
# 4            896         1       3     Mrs
# ..           ...       ...     ...     ...
# 413         1305         0       3      Mr
# 414         1306         1       1     Mrs
# 415         1307         0       3      Mr
# 416         1308         0       3      Mr
# 417         1309         0       3  Master
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# ...

# %%
def func(x):
    items = x.split(', ')
    surname = items[0]
    return surname

series = df['Name'].apply(func)
series
# Out:
# 0              Kelly
# 1             Wilkes
# 2              Myles
# 3               Wirz
# 4           Hirvonen
#            ...
# 413          Spector
# 414    Oliva y Ocana
# 415          Saether
# 416             Ware
# 417            Peter
# Name: Name, Length: 418, dtype: object

# %%
df.insert(i + 1, 'surname', series)
df
# Out:
#      PassengerId  Survived  Pclass   title  \
# 0            892         0       3      Mr
# 1            893         1       3     Mrs
# 2            894         0       2      Mr
# 3            895         0       3      Mr
# 4            896         1       3     Mrs
# ..           ...       ...     ...     ...
# 413         1305         0       3      Mr
# 414         1306         1       1     Mrs
# 415         1307         0       3      Mr
# 416         1308         0       3      Mr
# 417         1309         0       3  Master
#
#                                              Name        surname     Sex  \
# 0                                Kelly, Mr. James          Kelly    male
# 1                Wilkes, Mrs. James (Ellen Needs)         Wilkes  female
# 2                       Myles, Mr. Thomas Francis          Myles    male
# 3                                Wirz, Mr. Albert           Wirz    male
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)       Hirvonen  female
# ...

# %%
df = df.drop('Name', axis = 1)
df
# Out:
#      PassengerId  Survived  Pclass   title        surname     Sex   Age  \
# 0            892         0       3      Mr          Kelly    male  34.5
# 1            893         1       3     Mrs         Wilkes  female  47.0
# 2            894         0       2      Mr          Myles    male  62.0
# 3            895         0       3      Mr           Wirz    male  27.0
# 4            896         1       3     Mrs       Hirvonen  female  22.0
# ..           ...       ...     ...     ...            ...     ...   ...
# 413         1305         0       3      Mr        Spector    male   NaN
# 414         1306         1       1     Mrs  Oliva y Ocana  female  39.0
# 415         1307         0       3      Mr        Saether    male  38.5
# 416         1308         0       3      Mr           Ware    male   NaN
# 417         1309         0       3  Master          Peter    male   NaN
#
#      SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df['title'].value_counts()
# Out:
# Mr          240
# Miss         78
# Mrs          73
# Master       21
# Colonel       2
# Reverend      2
# Ms            1
# Dr            1
# Name: title, dtype: int64

# %%
filt = df['title'] == 'Ms'
filt
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Name: title, Length: 418, dtype: bool

# %%
df[filt]
# Out:
#     PassengerId  Survived  Pclass title     surname     Sex  Age  SibSp  \
# 88          980         1       3    Ms  O'Donoghue  female  NaN      0
#
#     Parch  Ticket  Fare Cabin Embarked
# 88      0  364856  7.75   NaN        Q

# %%
indices = df[filt].index
indices
# Out:
# Int64Index([88], dtype='int64')

# %%
df.loc[indices, 'title'] = 'Miss'

# %%
df['title'].value_counts()
# Out:
# Mr          240
# Miss         79
# Mrs          73
# Master       21
# Colonel       2
# Reverend      2
# Dr            1
# Name: title, dtype: int64

# %%
filt1 = df['title'] == 'Dr'
filt1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Name: title, Length: 418, dtype: bool

# %%
df[filt1]
# Out:
#      PassengerId  Survived  Pclass title surname   Sex   Age  SibSp  Parch  \
# 293         1185         0       1    Dr   Dodge  male  53.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 293  33638  81.8583   A34        S

# %%
indicex = df[filt1].index
indicex
# Out:
# Int64Index([293], dtype='int64')

# %%
df.loc[indicex, 'title'] = 'Mr'
df['title'].value_counts()
# Out:
# Mr          242
# Miss         78
# Mrs          73
# Master       21
# Colonel       2
# Reverend      2
# Name: title, dtype: int64

# %%
df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df = df.dropna(subset = ['Age'])
df
# Out:
#      PassengerId  Survived  Pclass title        surname     Sex   Age  SibSp  \
# 0            892         0       3    Mr          Kelly    male  34.5      0
# 1            893         1       3   Mrs         Wilkes  female  47.0      1
# 2            894         0       2    Mr          Myles    male  62.0      0
# 3            895         0       3    Mr           Wirz    male  27.0      0
# 4            896         1       3   Mrs       Hirvonen  female  22.0      1
# ..           ...       ...     ...   ...            ...     ...   ...    ...
# 409         1301         1       3  Miss        Peacock  female   3.0      1
# 411         1303         1       1   Mrs        Minahan  female  37.0      1
# 412         1304         1       3  Miss     Henriksson  female  28.0      0
# 414         1306         1       1   Mrs  Oliva y Ocana  female  39.0      0
# 415         1307         0       3    Mr        Saether    male  38.5      0
#
# ...

# %%
df['Age'] = df['Age'].astype('int8')
df
# Out:
# <ipython-input-39-500e475eed89>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'] = df['Age'].astype('int8')
#      PassengerId  Survived  Pclass title        surname     Sex  Age  SibSp  \
# 0            892         0       3    Mr          Kelly    male   34      0
# 1            893         1       3   Mrs         Wilkes  female   47      1
# 2            894         0       2    Mr          Myles    male   62      0
# 3            895         0       3    Mr           Wirz    male   27      0
# 4            896         1       3   Mrs       Hirvonen  female   22      1
# ..           ...       ...     ...   ...            ...     ...  ...    ...
# 409         1301         1       3  Miss        Peacock  female    3      1
# ...

# %%
df['Ticket'].unique()
# Out:
# array(['330911', '363272', '240276', '315154', '3101298', '7538',
#        '330972', '248738', '2657', 'A/4 48871', '694', '21228', '24065',
#        'W.E.P. 5734', 'SC/PARIS 2167', '233734', '2692',
#        'STON/O2. 3101270', '2696', 'PC 17603', 'C 17368', 'PC 17597',
#        'PC 17608', 'A/5. 3337', '113509', '2698', '113054', 'SC/AH 3085',
#        'C.A. 31029', 'C.A. 2315', '13236', '2682', '315087', '345768',
#        '349256', 'SOTON/O.Q. 3101263', '237249', '11753',
#        'STON/O 2. 3101291', 'PC 17594', '11813', 'C.A. 37671', '13695',
#        'SC/PARIS 2168', '29105', '19950', '382652', '349230', '348122',
#        '349232', '237216', '347090', '334914', '330963', '113796', '2543',
#        '382653', '349211', '3101297', 'PC 17562', '113503', '11770',
#        '248744', '368702', '2678', 'PC 17483', '19924', '330844',
#        'A/4 31416', '29103', '347072', 'F.C. 12750', '13905', '350033',
#        '19877', 'STON/O 2. 3101268', '347471', 'A./5. 3338', '11778',
# ...

# %%
table = str.maketrans('', '', '0123456789./ ')
table
# Out:
# {48: None,
#  49: None,
#  50: None,
#  51: None,
#  52: None,
#  53: None,
#  54: None,
#  55: None,
#  56: None,
#  57: None,
#  46: None,
#  47: None,
#  32: None}

# %%
def func(x):
    s = x.translate(table)
    return int(bool(s))

series = df['Ticket'].apply(func)
series
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 409    1
# 411    0
# 412    0
# 414    1
# 415    1
# Name: Ticket, Length: 332, dtype: int64

# %%
i = df.columns.tolist().index('Ticket')
i
# Out:
# 9

# %%
df.insert(i, 'ticket_alphanumeric', series)
df
# Out:
#      PassengerId  Survived  Pclass title        surname     Sex  Age  SibSp  \
# 0            892         0       3    Mr          Kelly    male   34      0
# 1            893         1       3   Mrs         Wilkes  female   47      1
# 2            894         0       2    Mr          Myles    male   62      0
# 3            895         0       3    Mr           Wirz    male   27      0
# 4            896         1       3   Mrs       Hirvonen  female   22      1
# ..           ...       ...     ...   ...            ...     ...  ...    ...
# 409         1301         1       3  Miss        Peacock  female    3      1
# 411         1303         1       1   Mrs        Minahan  female   37      1
# 412         1304         1       3  Miss     Henriksson  female   28      0
# 414         1306         1       1   Mrs  Oliva y Ocana  female   39      0
# 415         1307         0       3    Mr        Saether    male   38      0
#
# ...

# %%
df['Ticket'].nunique()
# Out:
# 285

# %%
df.drop('Ticket', axis = 1, inplace = True)
df
# Out:
# <ipython-input-46-a0e428bd8f84>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('Ticket', axis = 1, inplace = True)
#      PassengerId  Survived  Pclass title        surname     Sex  Age  SibSp  \
# 0            892         0       3    Mr          Kelly    male   34      0
# 1            893         1       3   Mrs         Wilkes  female   47      1
# 2            894         0       2    Mr          Myles    male   62      0
# 3            895         0       3    Mr           Wirz    male   27      0
# 4            896         1       3   Mrs       Hirvonen  female   22      1
# ..           ...       ...     ...   ...            ...     ...  ...    ...
# 409         1301         1       3  Miss        Peacock  female    3      1
# ...

# %%
q1 = df['Fare'].quantile(0.25)
q3 = df['Fare'].quantile(0.75)
iqr = q3 - q1
lower_whisker = q1 - 1.5 * iqr
if lower_whisker < 0:
    lower_whisker = 0
upper_whisker = q3 + 1.5 * iqr

q1, q3, iqr, lower_whisker, upper_whisker
# Out:
# (8.05, 40.63335, 32.583349999999996, 0, 89.508375)

# %%
filt = df['Fare'] > upper_whisker
filt.sum()
# Out:
# 34

# %%
df.loc[filt, 'Survived'].mean()
# Out:
# 0.5882352941176471

# %%
df['Cabin'].nunique()
# Out:
# 72

# %%
def func(x):
    if type(x) == str:
        s = x.translate(table)
        s = ''.join(sorted(set(s)))
        return s
    

series = df['Cabin'].apply(func)
series.unique()
# Out:
# array([None, 'B', 'E', 'A', 'C', 'D', 'FG', 'F', 'G', 'EF'], dtype=object)

# %%
i = df.columns.tolist().index('Cabin')
df.insert(i, 'emam', series)
df
# Out:
#      PassengerId  Survived  Pclass title        surname     Sex  Age  SibSp  \
# 0            892         0       3    Mr          Kelly    male   34      0
# 1            893         1       3   Mrs         Wilkes  female   47      1
# 2            894         0       2    Mr          Myles    male   62      0
# 3            895         0       3    Mr           Wirz    male   27      0
# 4            896         1       3   Mrs       Hirvonen  female   22      1
# ..           ...       ...     ...   ...            ...     ...  ...    ...
# 409         1301         1       3  Miss        Peacock  female    3      1
# 411         1303         1       1   Mrs        Minahan  female   37      1
# 412         1304         1       3  Miss     Henriksson  female   28      0
# 414         1306         1       1   Mrs  Oliva y Ocana  female   39      0
# 415         1307         0       3    Mr        Saether    male   38      0
#
# ...

# %%
df.drop('Cabin', axis = 1, inplace = True)
df
# Out:
# <ipython-input-54-d62470ff0089>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('Cabin', axis = 1, inplace = True)
#      PassengerId  Survived  Pclass title        surname     Sex  Age  SibSp  \
# 0            892         0       3    Mr          Kelly    male   34      0
# 1            893         1       3   Mrs         Wilkes  female   47      1
# 2            894         0       2    Mr          Myles    male   62      0
# 3            895         0       3    Mr           Wirz    male   27      0
# 4            896         1       3   Mrs       Hirvonen  female   22      1
# ..           ...       ...     ...   ...            ...     ...  ...    ...
# 409         1301         1       3  Miss        Peacock  female    3      1
# ...

# %%
df.drop(['surname'], axis = 1, inplace = True)
df
# Out:
# <ipython-input-55-c89ab97262f5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['surname'], axis = 1, inplace = True)
#      PassengerId  Survived  Pclass title     Sex  Age  SibSp  Parch  \
# 0            892         0       3    Mr    male   34      0      0
# 1            893         1       3   Mrs  female   47      1      0
# 2            894         0       2    Mr    male   62      0      0
# 3            895         0       3    Mr    male   27      0      0
# 4            896         1       3   Mrs  female   22      1      1
# ..           ...       ...     ...   ...     ...  ...    ...    ...
# 409         1301         1       3  Miss  female    3      1      1
# 411         1303         1       1   Mrs  female   37      1      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 332 entries, 0 to 415
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   PassengerId          332 non-null    int64
#  1   Survived             332 non-null    int8
#  2   Pclass               332 non-null    int64
#  3   title                332 non-null    object
#  4   Sex                  332 non-null    object
#  5   Age                  332 non-null    int8
#  6   SibSp                332 non-null    int64
#  7   Parch                332 non-null    int64
#  8   ticket_alphanumeric  332 non-null    int64
#  9   Fare                 331 non-null    float64
#  10  emam                 87 non-null     object
#  11  Embarked             332 non-null    object
# dtypes: float64(1), int64(5), int8(2), object(4)
# memory usage: 29.2+ KB

# %%
df.dropna(subset = ['Fare', 'Embarked'], inplace = True)
df
# Out:
# <ipython-input-57-ff6058a2593e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset = ['Fare', 'Embarked'], inplace = True)
#      PassengerId  Survived  Pclass title     Sex  Age  SibSp  Parch  \
# 0            892         0       3    Mr    male   34      0      0
# 1            893         1       3   Mrs  female   47      1      0
# 2            894         0       2    Mr    male   62      0      0
# 3            895         0       3    Mr    male   27      0      0
# 4            896         1       3   Mrs  female   22      1      1
# ..           ...       ...     ...   ...     ...  ...    ...    ...
# 409         1301         1       3  Miss  female    3      1      1
# 411         1303         1       1   Mrs  female   37      1      0
# ...

# %%
df.drop('emam', axis = 1, inplace = True)
df
# Out:
# <ipython-input-60-c544b3a7fd79>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('emam', axis = 1, inplace = True)
#      PassengerId  Survived  Pclass title     Sex  Age  SibSp  Parch  \
# 0            892         0       3    Mr    male   34      0      0
# 1            893         1       3   Mrs  female   47      1      0
# 2            894         0       2    Mr    male   62      0      0
# 3            895         0       3    Mr    male   27      0      0
# 4            896         1       3   Mrs  female   22      1      1
# ..           ...       ...     ...   ...     ...  ...    ...    ...
# 409         1301         1       3  Miss  female    3      1      1
# 411         1303         1       1   Mrs  female   37      1      0
# ...

# %%
df.groupby('Embarked')['Survived'].mean()
# Out:
# Embarked
# C    0.451220
# Q    0.545455
# S    0.343612
# Name: Survived, dtype: float64

# %%
df['Embarked'] = df['Embarked'].replace({'C': 1, 'S': 2, 'Q': 3})
df
# Out:
# <ipython-input-62-d0fa2ba8afac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Embarked'] = df['Embarked'].replace({'C': 1, 'S': 2, 'Q': 3})
#      PassengerId  Survived  Pclass title     Sex  Age  SibSp  Parch  \
# 0            892         0       3    Mr    male   34      0      0
# 1            893         1       3   Mrs  female   47      1      0
# 2            894         0       2    Mr    male   62      0      0
# 3            895         0       3    Mr    male   27      0      0
# 4            896         1       3   Mrs  female   22      1      1
# ..           ...       ...     ...   ...     ...  ...    ...    ...
# 409         1301         1       3  Miss  female    3      1      1
# ...

# %%
X = df.drop('Survived', axis = 1)
y = df['Survived']

# %%
df
# Out:
#      PassengerId  Survived  Pclass title     Sex  Age  SibSp  Parch  \
# 0            892         0       3    Mr    male   34      0      0
# 1            893         1       3   Mrs  female   47      1      0
# 2            894         0       2    Mr    male   62      0      0
# 3            895         0       3    Mr    male   27      0      0
# 4            896         1       3   Mrs  female   22      1      1
# ..           ...       ...     ...   ...     ...  ...    ...    ...
# 409         1301         1       3  Miss  female    3      1      1
# 411         1303         1       1   Mrs  female   37      1      0
# 412         1304         1       3  Miss  female   28      0      0
# 414         1306         1       1   Mrs  female   39      0      0
# 415         1307         0       3    Mr    male   38      0      0
#
#      ticket_alphanumeric      Fare  Embarked
# 0                      0    7.8292         3
# 1                      0    7.0000         2
# ...

# %%
df['Sex'] = df['Sex'].replace({'female': '1', 
                                   'male': '0'})
# Out:
# <ipython-input-66-8088cea87b35>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sex'] = df['Sex'].replace({'female': '1',

# %%
df['title'] = df['title'].replace({'Miss':  '1', 
                                   'Master':'0',
                                   'Mr':    '2',
                                   'Mrs' :  '3',
                                   'Colonel':'4',
                                   'Reverend':'5' })
# Out:
# <ipython-input-67-2adb09827513>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['title'] = df['title'].replace({'Miss':  '1',
